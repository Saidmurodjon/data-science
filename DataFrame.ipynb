# %% [markdown]
# <a href="https://colab.research.google.com/github/Saidmurodjon/data-science/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
    'Yil':[2021,2020,2019,2028,2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9,32.5,31.0,29.8,28.7,27.2],
    'Temp': [1.54,1.44,1.39,1.32,1.29,1.26,1.24,1.23],
    }
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.44
# 2  2019        32.9  1.39

# %%
df.shape
# Out:
# (8, 3)

# %%
df =pd.DataFrame(data,columns=['Yil','Temp','Aholi soni','Yosh'], index=['bir',2,3,4,5,6,7,8])
df
# Out:
#       Yil  Temp  Aholi soni Yosh
# bir  2021  1.54        33.9  NaN
# 2    2020  1.44        33.5  NaN
# 3    2019  1.39        32.9  NaN
# 4    2028  1.32        32.5  NaN
# 5    2017  1.29        31.0  NaN
# 6    2016  1.26        29.8  NaN
# 7    2015  1.24        28.7  NaN
# 8    2010  1.23        27.2  NaN

# %%
df['Aholi soni']
# Out:
# bir    33.9
# 2      33.5
# 3      32.9
# 4      32.5
# 5      31.0
# 6      29.8
# 7      28.7
# 8      27.2
# Name: Aholi soni, dtype: float64

# %%
df.Temp
# Out:
# bir    1.54
# 2      1.44
# 3      1.39
# 4      1.32
# 5      1.29
# 6      1.26
# 7      1.24
# 8      1.23
# Name: Temp, dtype: float64

# %%
df
# Out:
#       Yil  Temp  Aholi soni Yosh
# bir  2021  1.54        33.9  NaN
# 2    2020  1.44        33.5  NaN
# 3    2019  1.39        32.9  NaN
# 4    2028  1.32        32.5  NaN
# 5    2017  1.29        31.0  NaN
# 6    2016  1.26        29.8  NaN
# 7    2015  1.24        28.7  NaN
# 8    2010  1.23        27.2  NaN

# %%
val = pd.Series([1700,1600,1500],index=['bir',4,8])
df.Yosh = val

# %%
df
# Out:
#       Yil  Temp  Aholi soni    Yosh
# bir  2021  1.54        33.9  1700.0
# 2    2020  1.44        33.5     NaN
# 3    2019  1.39        32.9     NaN
# 4    2028  1.32        32.5  1600.0
# 5    2017  1.29        31.0     NaN
# 6    2016  1.26        29.8     NaN
# 7    2015  1.24        28.7     NaN
# 8    2010  1.23        27.2  1500.0

# %%
import numpy as np
val = [34,12,23,12,12,34,65,45]
df.Yosh = val
df
# Out:
#       Yil  Temp  Aholi soni  Yosh
# bir  2021  1.54        33.9    34
# 2    2020  1.44        33.5    12
# 3    2019  1.39        32.9    23
# 4    2028  1.32        32.5    12
# 5    2017  1.29        31.0    12
# 6    2016  1.26        29.8    34
# 7    2015  1.24        28.7    65
# 8    2010  1.23        27.2    45

# %%
df['Katta yosh']=df.Yosh>18
df
# Out:
#       Yil  Temp  Aholi soni  Yosh  Katta yosh
# bir  2021  1.54        33.9    34        True
# 2    2020  1.44        33.5    12       False
# 3    2019  1.39        32.9    23        True
# 4    2028  1.32        32.5    12       False
# 5    2017  1.29        31.0    12       False
# 6    2016  1.26        29.8    34        True
# 7    2015  1.24        28.7    65        True
# 8    2010  1.23        27.2    45        True

# %%
del df['Katta yosh']

# %%
df
# Out:
#       Yil  Temp  Aholi soni  Yosh
# bir  2021  1.54        33.9    34
# 2    2020  1.44        33.5    12
# 3    2019  1.39        32.9    23
# 4    2028  1.32        32.5    12
# 5    2017  1.29        31.0    12
# 6    2016  1.26        29.8    34
# 7    2015  1.24        28.7    65
# 8    2010  1.23        27.2    45
