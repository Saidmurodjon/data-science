# %% [markdown]
# <a href="https://colab.research.google.com/github/Saidmurodjon/data-science/blob/main/Qayta_indekslash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Yil":range(2021,2026),
    "Aholi soni":[10000,20000,30000,40000,50000],
    "Temp":[1.54,1.48,1.62,1.65,1.66], # Corrected length of Temp list
    "Zichlik":[1000,2000,3000,4000,5000]
        }
df = pd.DataFrame(data)
print(df)
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2021       10000  1.54     1000
# 1  2022       20000  1.48     2000
# 2  2023       30000  1.62     3000
# 3  2024       40000  1.65     4000
# 4  2025       50000  1.66     5000

# %%
df.index = [21,20,19,18,17]
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 21  2021       10000  1.54     1000
# 20  2022       20000  1.48     2000
# 19  2023       30000  1.62     3000
# 18  2024       40000  1.65     4000
# 17  2025       50000  1.66     5000

# %%
#Reindex
ind = [21,20,19,18,17]
ind.sort()
df.reindex(ind)
ind
# Out:
# [17, 18, 19, 20, 21]

# %%
df.reindex(ind) #yangi data frame  yaratadi
df = df.reindex(ind) #df saqllandi
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 17  2025       50000  1.66     5000
# 18  2024       40000  1.65     4000
# 19  2023       30000  1.62     3000
# 20  2022       20000  1.48     2000
# 21  2021       10000  1.54     1000

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 17  2025       50000  1.66     5000
# 18  2024       40000  1.65     4000
# 19  2023       30000  1.62     3000
# 20  2022       20000  1.48     2000
# 21  2021       10000  1.54     1000

# %%
df.reindex(index=range(10,22), method='nearest')
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 10  2025       50000  1.66     5000
# 11  2025       50000  1.66     5000
# 12  2025       50000  1.66     5000
# 13  2025       50000  1.66     5000
# 14  2025       50000  1.66     5000
# 15  2025       50000  1.66     5000
# 16  2025       50000  1.66     5000
# 17  2025       50000  1.66     5000
# 18  2024       40000  1.65     4000
# 19  2023       30000  1.62     3000
# 20  2022       20000  1.48     2000
# 21  2021       10000  1.54     1000

# %%
df2 = df.reindex(columns=['Aholi soni','Temp'], fill_value=0)

# %%
df2.sample(3)
# Out:
#     Aholi soni  Temp
# 20       20000  1.48
# 21       10000  1.54
# 17       50000  1.66

# %%
df.loc[[19,17,20],["Aholi soni","Temp"]]
# Out:
#     Aholi soni  Temp
# 19       30000  1.62
# 17       50000  1.66
# 20       20000  1.48

# %% [markdown]
# **Qator va ustunlarni tashlab yuborish**

# %%
df.drop(17) #qatrlarni tashlab yuborish yangi dataFrame yaratiladi
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 18  2024       40000  1.65     4000
# 19  2023       30000  1.62     3000
# 20  2022       20000  1.48     2000
# 21  2021       10000  1.54     1000

# %%
df.drop("Yil", axis=1) #Ustunlarni tashlab yuborish bunda yangi dataFrame yaratiladi
#Yangi DataFrame ni saqlab qolish uchun
#df.drop("Yil", axis='columns', inplace=True)
# Eski DataFrame yo'q bo'lib ketadi!  Foydalanishda ehtiyot bo'lish kerak
# Out:
#     Aholi soni  Temp  Zichlik
# 17       50000  1.66     5000
# 18       40000  1.65     4000
# 19       30000  1.62     3000
# 20       20000  1.48     2000
# 21       10000  1.54     1000

# %%
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 17  2025       50000  1.66     5000
# 18  2024       40000  1.65     4000
# 19  2023       30000  1.62     3000
# 20  2022       20000  1.48     2000
# 21  2021       10000  1.54     1000

# %%
df.drop([19,17,21],inplace=True)
df
# Out:
#      Yil  Aholi soni  Temp  Zichlik
# 18  2024       40000  1.65     4000
# 20  2022       20000  1.48     2000
