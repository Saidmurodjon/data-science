# %% [markdown]
# <a href="https://colab.research.google.com/github/Saidmurodjon/data-science/blob/main/Indekslash_qator_ustun_tanlash%2C_filtrlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Yil":range(2011,2019), # Corrected range to match length of other lists
    "Aholi soni":[30.2,30.5,31,32,33,34,35,36],
    "Temp":[1.54,1.48,1.62,1.65,1.66,1.65,1.66,1.65], # Corrected length of Temp list
    "Zichlik":[1000,2000,3000,4000,5000,2000,3000,4000]
        }
df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2011        30.2  1.54     1000
# 1  2012        30.5  1.48     2000
# 2  2013        31.0  1.62     3000
# 3  2014        32.0  1.65     4000
# 4  2015        33.0  1.66     5000
# 5  2016        34.0  1.65     2000
# 6  2017        35.0  1.66     3000
# 7  2018        36.0  1.65     4000

# %%
#data= df["Temp"]
data
# Out:
# {'Yil': range(2011, 2019),
#  'Aholi soni': [30.2, 30.5, 31, 32, 33, 34, 35, 36],
#  'Temp': [1.54, 1.48, 1.62, 1.65, 1.66, 1.65, 1.66, 1.65],
#  'Zichlik': [1000, 2000, 3000, 4000, 5000, 2000, 3000, 4000]}

# %%
type(data)
# Out:
# dict

# %%
#data = df[["Temp","Yil"]]
#type(data)

# %%
df
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2011        30.2  1.54     1000
# 1  2012        30.5  1.48     2000
# 2  2013        31.0  1.62     3000
# 3  2014        32.0  1.65     4000
# 4  2015        33.0  1.66     5000
# 5  2016        34.0  1.65     2000
# 6  2017        35.0  1.66     3000
# 7  2018        36.0  1.65     4000

# %%
# df[0:4]

# %%
df.iloc[[1,3]]
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 1  2012        30.5  1.48     2000
# 3  2014        32.0  1.65     4000
